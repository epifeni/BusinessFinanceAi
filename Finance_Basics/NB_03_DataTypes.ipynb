# %% [markdown]
# # Part 1: Python Basics - Code Time Value of Money and Capital Budgeting

# %% [markdown]
# ## Section 3: Objects, Data Types, Operators & Functional Programming

# %% [markdown]
# ### Data Types

# %%
100
# Out:
# 100

# %%
type(100)
# Out:
# int

# %%
PV = 100 / 1.03
PV
# Out:
# 97.08737864077669

# %%
type(PV)
# Out:
# float

# %%
type(1.03)
# Out:
# float

# %%
type(1.)
# Out:
# float

# %%
1.
# Out:
# 1.0

# %%
cf = [100, 50, 10]
cf
# Out:
# [100, 50, 10]

# %%
type(cf)
# Out:
# list

# %%
n = range(10)
n
# Out:
# range(0, 10)

# %%
type(n)
# Out:
# range

# %%
type(print)
# Out:
# builtin_function_or_method

# %%
print(cf)
# Out:
# [100, 50, 10]

# %%
a = print

# %%
a(cf)
# Out:
# [100, 50, 10]

# %%
"Microsoft"
# Out:
# 'Microsoft'

# %%
type("Microsoft")
# Out:
# str

# %%
company_name = "Microsoft"

# %%
company_name
# Out:
# 'Microsoft'

# %%
True
# Out:
# True

# %%
type(True)
# Out:
# bool

# %%
False
# Out:
# False

# %%
type(False)
# Out:
# bool

# %%
100 / 1.03
# Out:
# 97.08737864077669

# %%
"Microsoft" / 1.03
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 "Microsoft" / 1.03
#
# TypeError: unsupported operand type(s) for /: 'str' and 'float'

# %% [markdown]
# ### Excursus: Dynamic Typing

# %%
a = 100
a
# Out:
# 100

# %%
type(a)
# Out:
# int

# %%
a = "Facebook"
a
# Out:
# 'Facebook'

# %%
type(a)
# Out:
# str

# %%
a = [100, 20, 30]
a
# Out:
# [100, 20, 30]

# %%
type(a)
# Out:
# list

# %% [markdown]
# ### Build-in Functions

# %%
PV = 100
r = 0.03
n = 1
FV = 100 * 1.03

# %%
print(FV)
# Out:
# 103.0

# %%
print("Facebook")
# Out:
# Facebook

# %%
print([100, 20, 30])
# Out:
# [100, 20, 30]

# %%
print(PV, r, n, FV, sep = "\n")
# Out:
# 100
# 0.03
# 1
# 103.0

# %%
print(PV, r, n, FV, sep = ", ")
# Out:
# 100, 0.03, 1, 103.0

# %%
cf = [-200, 20, 50, 70, 100, 50]
cf
# Out:
# [-200, 20, 50, 70, 100, 50]

# %%
len(cf)
# Out:
# 6

# %%
len("Facebook")
# Out:
# 8

# %%
len(8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 len(8)
#
# TypeError: object of type 'int' has no len()

# %%
sum(cf)
# Out:
# 90

# %%
sum("Facebook")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 sum("Facebook")
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
min(cf)
# Out:
# -200

# %%
min("Facebook") # capital letters have lower ASCII values
# Out:
# 'F'

# %%
min("facebook")
# Out:
# 'a'

# %%
max(cf)
# Out:
# 100

# %%
max("Facebook")
# Out:
# 'o'

# %% [markdown]
# ### Integers

# %%
type(100)
# Out:
# int

# %%
100 + 50
# Out:
# 150

# %%
100 - 50
# Out:
# 50

# %%
100 * 10
# Out:
# 1000

# %%
100 / 10
# Out:
# 10.0

# %%
type(100 / 10) # division always results in float
# Out:
# float

# %%
I0 = 100 #Investment at time stamp 0 (I0)
I0
# Out:
# 100

# %% [markdown]
# __The first built-in method__

# %%
I0.bit_length()
# Out:
# 7

# %% [markdown]
# ### Floats

# %%
type(1.04)
# Out:
# float

# %%
100 / 10
# Out:
# 10.0

# %%
type(100 / 10)
# Out:
# float

# %%
r = 1.04

# %%
100 * r
# Out:
# 104.0

# %%
r.is_integer()
# Out:
# False

# %%
r.as_integer_ratio() # float is represented as a ratio of two integers
# Out:
# (1170935903116329, 1125899906842624)

# %%
0.1 + 0.1 + 0.1 == 0.3
# Out:
# False

# %%
0.1
# Out:
# 0.1

# %%
0.1 + 0.1 + 0.1
# Out:
# 0.30000000000000004

# %%
0.3
# Out:
# 0.3

# %%
format(0.1, ".20f") # does not have an exact binary representation
# Out:
# '0.10000000000000000555'

# %%
format(0.3, ".20f") # does not have an exact binary representation
# Out:
# '0.29999999999999998890'

# %%
1/8 # has a finite representation in binary floating point
# Out:
# 0.125

# %%
format(1/8, ".20f")
# Out:
# '0.12500000000000000000'

# %%
format(1/32, ".20f")
# Out:
# '0.03125000000000000000'

# %%
round(0.1, 1)
# Out:
# 0.1

# %%
format(round(0.1, 1), ".20f")
# Out:
# '0.10000000000000000555'

# %% [markdown]
# ### Rounding Floats (and Integers)

# %%
round(1.3454, 0)
# Out:
# 1.0

# %%
round(1.7657)
# Out:
# 2

# %%
round(1.3454, 1)
# Out:
# 1.3

# %%
round(1.3454, 2)
# Out:
# 1.35

# %%
format(round(1.3454, 2), ".20f")
# Out:
# '1.35000000000000008882'

# %%
round(13, -1) # rounds down to nearest ten
# Out:
# 10

# %%
round(17, -1)
# Out:
# 20

# %%
round(217, -2)
# Out:
# 200

# %%
round(257, -2)
# Out:
# 300

# %%
round(1.5)
# Out:
# 2

# %%
round(2.5) # bankers rounding. Rounds to nearest even number
# Out:
# 2

# %%
1.5 + 2.5 + 3.5 + 4.5
# Out:
# 12.0

# %%
1 + 2 + 3 + 4
# Out:
# 10

# %%
round(1.5) + round(2.5) + round(3.5) + round(4.5) # bankers rounding
# Out:
# 12

# %% [markdown]
# ### More on Lists

# %%
cf = [-200, 20, 50, 70, 100, 50]
cf
# Out:
# [-200, 20, 50, 70, 100, 50]

# %%
type(cf)
# Out:
# list

# %%
len(cf)
# Out:
# 6

# %%
sum(cf)
# Out:
# 90

# %%
max(cf)
# Out:
# 100

# %%
min(cf)
# Out:
# -200

# %%
cf[0]
# Out:
# -200

# %%
cf[-2]
# Out:
# 100

# %%
cf.index(20)
# Out:
# 1

# %%
enumerate(cf)

# %%
list(enumerate(cf))
# Out:
# [(0, -200), (1, 20), (2, 50), (3, 70), (4, 100), (5, 50)]

# %%
cf.count(20)
# Out:
# 1

# %%
l = [100, 50.2, "Facebook", True]

# %%
l
# Out:
# [100, 50.2, 'Facebook', True]

# %%
for i in l:
    print(type(i))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# ### Lists and element-wise Operations

# %%
cf = [100, 10, 20, 50, 30, 25]

# %%
cf * 1.1 # expecting 10% higher cash flows
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[113], line 1
# ----> 1 cf * 1.1
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
cf - 20 # adjustment to each cash flow of addition fixed cost of $20 per year
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[114], line 1
# ----> 1 cf - 20
#
# TypeError: unsupported operand type(s) for -: 'list' and 'int'

# %%
l = [1, 2, 3]

# %%
l.append(4)

# %%
l
# Out:
# [1, 2, 3, 4]

# %%
cf_new = []

# %%
cf_new
# Out:
# []

# %%
cf_new = []
for i in cf:
    new = i * 1.1 # expecting 10% higher cash flows
    cf_new.append(new)
print(cf_new)
# Out:
# [110.00000000000001, 11.0, 22.0, 55.00000000000001, 33.0, 27.500000000000004]

# %%
cf_new = []
for i in cf:
    new = i - 20
    cf_new.append(new) # adjustment to each cash flow of addition fixed cost of $20 per year
print(cf_new)
# Out:
# [80, -10, 0, 30, 10, 5]

# %%
cf * 3
# Out:
# [100, 10, 20, 50, 30, 25, 100, 10, 20, 50, 30, 25, 100, 10, 20, 50, 30, 25]

# %% [markdown]
# ### Slicing Lists

# %%
cf = [-200, 20, 50, 70, 100, 50]
cf
# Out:
# [-200, 20, 50, 70, 100, 50]

# %%
cf[1:4]
# Out:
# [20, 50, 70]

# %%
cf[0:1]
# Out:
# [-200]

# %%
cf[:2]
# Out:
# [-200, 20]

# %%
cf[1:]
# Out:
# [20, 50, 70, 100, 50]

# %%
cf[:]
# Out:
# [-200, 20, 50, 70, 100, 50]

# %%
cf[:-1]
# Out:
# [-200, 20, 50, 70, 100]

# %%
cf[-3:]
# Out:
# [70, 100, 50]

# %%
cf[::2] # every second element
# Out:
# [-200, 50, 100]

# %%
cf[1:5:2]
# Out:
# [20, 70]

# %%
cf[1:5:3]
# Out:
# [20, 100]

# %%
cf[::-1]
# Out:
# [50, 100, 70, 50, 20, -200]

# %% [markdown]
# ### Changing Elements in Lists

# %%
cf = [100, 10, 20, 50, 30, 25]
cf
# Out:
# [100, 10, 20, 50, 30, 25]

# %% [markdown]
# Change initial saving to 50 USD.

# %%
cf[0] = 50

# %%
cf
# Out:
# [50, 10, 20, 50, 30, 25]

# %% [markdown]
# Change ongoing savings to 40 USD p.a.

# %%
cf[1:] = 40 # depost $40 to each cash flow except the first one
# braodcasting does not work with lists
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[139], line 1
# ----> 1 cf[1:] = 40
#
# TypeError: must assign iterable to extended slice

# %%
cf[1:] = [40, 70, 40, 40, 10]

# %%
cf
# Out:
# [50, 40, 70, 40, 40, 10]

# %% [markdown]
# ### Sorting and Reversing Lists

# %%
n = list(range(6))
n
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
n[::-1]
# Out:
# [5, 4, 3, 2, 1, 0]

# %%
n # did not change the original list
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
n = n[::-1] # n is refers to a new object

# %%
n
# Out:
# [5, 4, 3, 2, 1, 0]

# %%
n.reverse() #changes the original list in place

# %%
n
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
cf = [100, 10, 20, 50, 30, 25]
cf
# Out:
# [100, 10, 20, 50, 30, 25]

# %%
cf.sort()

# %%
cf
# Out:
# [10, 20, 25, 30, 50, 100]

# %%
cf.sort(reverse = True)

# %%
cf
# Out:
# [100, 50, 30, 25, 20, 10]

# %% [markdown]
# ### Adding and removing elements to/from Lists

# %%
cf = [-200, 20, 50, 70, 100, 50] # buying an additional asset with an initial outlay of $200
cf
# Out:
# [-200, 20, 50, 70, 100, 50]

# %%
cf + 25 # adding anothe yearly cash flow of $25
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[156], line 1
# ----> 1 cf + 25
#
# TypeError: can only concatenate list (not "int") to list

# %%
cf + [25] # adding anothe yearly cash flow of $25
# Out:
# [-200, 20, 50, 70, 100, 50, 25]

# %%
cf
# Out:
# [-200, 20, 50, 70, 100, 50]

# %%
cf = cf + [25]

# %%
cf
# Out:
# [-200, 20, 50, 70, 100, 50, 25]

# %%
cf.append(10)

# %%
cf
# Out:
# [-200, 20, 50, 70, 100, 50, 25, 10]

# %%
cf + [5, 2]
# Out:
# [-200, 20, 50, 70, 100, 50, 25, 10, 5, 2]

# %%
cf
# Out:
# [-200, 20, 50, 70, 100, 50, 25, 10]

# %%
cf.extend([5, 2])

# %%
cf
# Out:
# [-200, 20, 50, 70, 100, 50, 25, 10, 5, 2]

# %%
cf.remove(2)

# %%
cf
# Out:
# [-200, 20, 50, 70, 100, 50, 25, 10, 5]

# %%
cf - [25, 10, 5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[169], line 1
# ----> 1 cf - [25, 10, 5]
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
cf = cf[:-3]

# %%
cf
# Out:
# [-200, 20, 50, 70, 100, 50]

# %%
cf.pop()
# Out:
# 50

# %%
cf
# Out:
# [-200, 20, 50, 70, 100]

# %%
cf.insert(2, 100) # insert 100 at index 2

# %%
cf
# Out:
# [-200, 20, 100, 50, 70, 100]

# %% [markdown]
# ### Mutable vs Immutable Objects (Part 1)

# %%
r1 = 0.05

# %%
r2 = r1

# %%
r2
# Out:
# 0.05

# %%
r1 += 0.01

# %%
print(r1, r2)
# Out:
# 0.060000000000000005 0.05

# %%
cf1 = [100, 10, 20, 50, 30, 25]
cf2 = cf1

# %%
cf2
# Out:
# [100, 10, 20, 50, 30, 25]

# %%
cf1[0] = 50

# %%
print(cf1, cf2) # list are mutable objects. we can change the contents of the list even though both variables point to the same object
# Out:
# [50, 10, 20, 50, 30, 25] [50, 10, 20, 50, 30, 25]

# %%
cf1 = [100, 10, 20, 50, 30, 25]
cf2 = cf1

# %%
cf1.append(15)

# %%
print(cf1, cf2)
# Out:
# [100, 10, 20, 50, 30, 25, 15] [100, 10, 20, 50, 30, 25, 15]

# %%
cf1 = [100, 10, 20, 50, 30, 25]
cf2 = cf1

# %%
cf1 = cf1 + [15]

# %%
print(cf1, cf2)
# Out:
# [100, 10, 20, 50, 30, 25, 15] [100, 10, 20, 50, 30, 25]

# %%
cf1 = [100, 10, 20, 50, 30, 25]
cf2 = cf1

# %%
cf1.sort()

# %%
cf1
# Out:
# [10, 20, 25, 30, 50, 100]

# %%
cf2
# Out:
# [10, 20, 25, 30, 50, 100]

# %% [markdown]
# ### Mutable vs Immutable Objects (Part 2)

# %%
cf1 = [100, 10, 20, 50, 30, 25]
cf2 = [100, 10, 20, 50, 30, 25]

# %%
cf1[0] = 50

# %%
print(cf1, cf2)
# Out:
# [50, 10, 20, 50, 30, 25] [100, 10, 20, 50, 30, 25]

# %%
cf1 = [100, 10, 20, 50, 30, 25]
cf2 = cf1[:]

# %%
cf2
# Out:
# [100, 10, 20, 50, 30, 25]

# %%
cf1[0] = 50

# %%
print(cf1, cf2)
# Out:
# [50, 10, 20, 50, 30, 25] [100, 10, 20, 50, 30, 25]

# %%
cf1 = [100, 10, 20, 50, 30, 25]
cf2 = cf1.copy() #recommended way to copy a list

# %%
cf2
# Out:
# [100, 10, 20, 50, 30, 25]

# %%
cf1[0] = 50

# %%
print(cf1, cf2)
# Out:
# [50, 10, 20, 50, 30, 25] [100, 10, 20, 50, 30, 25]

# %% [markdown]
# ### Tuples

# %%
cf = [-200, 20, 50, 70, 100, 50]
cf
# Out:
# [-200, 20, 50, 70, 100, 50]

# %%
enum = list(enumerate(cf))
enum
# Out:
# [(0, -200), (1, 20), (2, 50), (3, 70), (4, 100), (5, 50)]

# %%
tup = enum[0]
tup
# Out:
# (0, -200)

# %%
type(tup)
# Out:
# tuple

# %%
tup[0]
# Out:
# 0

# %%
tup[-1]
# Out:
# -200

# %%
tup[1] = -150 # tup are immutable objects. we cannot change the contents of the tuple
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[215], line 1
# ----> 1 tup[1] = -150
#
# TypeError: 'tuple' object does not support item assignment

# %%
tup.count(-200)
# Out:
# 1

# %%
tup.index(-200)
# Out:
# 1

# %%
pos, cf = tup

# %%
pos
# Out:
# 0

# %%
cf
# Out:
# -200

# %%
tup2 = (0, -150)

# %%
tup2
# Out:
# (0, -150)

# %%
tup3 = 0, -100

# %%
tup3
# Out:
# (0, -100)

# %%
l = list(tup)
l
# Out:
# [0, -200]

# %%
tuple(l)
# Out:
# (0, -200)

# %% [markdown]
# ### Dictionaries

# %%
stock = ["Facebook", "Microsoft", "Apple"]
price = [188.25, 144.61, 243.26]

# %%
{"Facebook": 188.25, "Microsoft":144.61, "Apple": 243.26}
# Out:
# {'Facebook': 188.25, 'Microsoft': 144.61, 'Apple': 243.26}

# %%
mapping = {"Facebook": 188.25, "Microsoft":144.61, "Apple": 243.26}

# %%
type(mapping)
# Out:
# dict

# %%
mapping["Facebook"]
# Out:
# 188.25

# %%
mapping["Facebook"] = 190.51

# %%
mapping["Google"] = 1298.22

# %%
mapping
# Out:
# {'Facebook': 190.51, 'Microsoft': 144.61, 'Apple': 243.26, 'Google': 1298.22}

# %%
mapping.keys()
# Out:
# dict_keys(['Facebook', 'Microsoft', 'Apple', 'Google'])

# %%
l = mapping.values()
l
# Out:
# dict_values([190.51, 144.61, 243.26, 1298.22])

# %%
type(l)
# Out:
# dict_values

# %%
list(l)
# Out:
# [190.51, 144.61, 243.26, 1298.22]

# %%
mapping.items()
# Out:
# dict_items([('Facebook', 190.51), ('Microsoft', 144.61), ('Apple', 243.26), ('Google', 1298.22)])

# %%
list(mapping.items())
# Out:
# [('Facebook', 190.51),
#  ('Microsoft', 144.61),
#  ('Apple', 243.26),
#  ('Google', 1298.22)]

# %%
for key, value in mapping.items():
    print(key, value)
# Out:
# Facebook 190.51
# Microsoft 144.61
# Apple 243.26
# Google 1298.22

# %%
mapping = {"Facebook": 188.25, "Facebook":190.51, "Apple": 243.26}

# %%
mapping
# Out:
# {'Facebook': 190.51, 'Apple': 243.26}

# %%
stock
# Out:
# ['Facebook', 'Microsoft', 'Apple']

# %%
price
# Out:
# [188.25, 144.61, 243.26]

# %%
zip(stock, price)

# %%
type(zip(stock, price))
# Out:
# zip

# %%
dict(zip(stock, price))
# Out:
# {'Facebook': 188.25, 'Microsoft': 144.61, 'Apple': 243.26}

# %%
for i in zip(stock, price):
    print(i)
# Out:
# ('Facebook', 188.25)
# ('Microsoft', 144.61)
# ('Apple', 243.26)

# %% [markdown]
# ### Intro to Strings

# %%
company_name = "Facebook Inc."

# %%
company_name
# Out:
# 'Facebook Inc.'

# %%
type(company_name)
# Out:
# str

# %%
company_name[0]
# Out:
# 'F'

# %%
company_name[3]
# Out:
# 'e'

# %%
company_name[8]
# Out:
# ' '

# %%
company_name[-1]
# Out:
# '.'

# %%
company_name[2:7]
# Out:
# 'ceboo'

# %%
company_name[0] = "f"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[259], line 1
# ----> 1 company_name[0] = "f"
#
# TypeError: 'str' object does not support item assignment

# %%
sentence =  "I invested $50 into Facebook!"

# %%
sentence
# Out:
# 'I invested $50 into Facebook!'

# %%
len(sentence)
# Out:
# 29

# %%
I0 = "100"
I0
# Out:
# '100'

# %%
type(I0)
# Out:
# str

# %%
I0 * 1.03
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[265], line 1
# ----> 1 I0 * 1.03
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
I0 + " USD"
# Out:
# '100 USD'

# %%
I0
# Out:
# '100'

# %%
int(I0)
# Out:
# 100

# %%
I0
# Out:
# '100'

# %%
I0 = int(I0)
I0
# Out:
# 100

# %%
type(I0)
# Out:
# int

# %%
I0 = str(I0)
I0
# Out:
# '100'

# %%
I0 = float(I0)
I0
# Out:
# 100.0

# %%
sentence.upper()
# Out:
# 'I INVESTED $50 INTO FACEBOOK!'

# %%
sentence.lower()
# Out:
# 'i invested $50 into facebook!'

# %%
sentence.capitalize()
# Out:
# 'I invested $50 into facebook!'

# %%
sentence.title()
# Out:
# 'I Invested $50 Into Facebook!'

# %%
sentence
# Out:
# 'I invested $50 into Facebook!'

# %%
sentence = sentence.lower()

# %%
sentence
# Out:
# 'i invested $50 into facebook!'

# %% [markdown]
# ### String Replacement

# %%
r = 0.05

# %%
"The interest rate is {}.".format(r)
# Out:
# 'The interest rate is 0.05.'

# %%
what = "interest rate"

# %%
"The {} is {}.".format(what, r)
# Out:
# 'The interest rate is 0.05.'

# %%
"The {} is {}.".format(what, 0.05)
# Out:
# 'The interest rate is 0.05.'

# %%
cf = [100, 10, 20, 50, 30, 25]

# %%
for i in cf:
    print("The Cashflow is {}!".format(i))
# Out:
# The Cashflow is 100!
# The Cashflow is 10!
# The Cashflow is 20!
# The Cashflow is 50!
# The Cashflow is 30!
# The Cashflow is 25!

# %%
for i in range(len(cf)):
    print("The Cashflow at t{} is {}!".format(i, cf[i]))
# Out:
# The Cashflow at t0 is 100!
# The Cashflow at t1 is 10!
# The Cashflow at t2 is 20!
# The Cashflow at t3 is 50!
# The Cashflow at t4 is 30!
# The Cashflow at t5 is 25!

# %% [markdown]
# ### Booleans

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
print(type(True), type(False))
# Out:
# <class 'bool'> <class 'bool'>

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
True + False
# Out:
# 1

# %%
True + 5
# Out:
# 6

# %%
False * 6
# Out:
# 0

# %%
True * 6
# Out:
# 6

# %% [markdown]
# ### Comparison, Logical and Membership Operators in Action

# %% [markdown]
# Comparison Operators

# %%
cf1 = 50
cf2 = 60

# %%
cf1 == cf2 #equal
# Out:
# False

# %%
cf1 != cf2 #not equal
# Out:
# True

# %%
cf1 > cf2 #greater than
# Out:
# False

# %%
cf1 >= cf2 #greater than or equal to
# Out:
# False

# %%
cf1 < cf2 #less than
# Out:
# True

# %%
cf1 <= cf2 #less than or equal to
# Out:
# True

# %% [markdown]
# Excursus: Identity Operators

# %%
r1 = 0.05

# %%
r2 = r1

# %%
r1 == r2 #equal
# Out:
# True

# %%
r1 is r2 #is referring to the same object
# Out:
# True

# %%
cf1 = [-100, 20, 30]
cf2 = cf1.copy()

# %%
cf1 == cf2 #equal
# Out:
# True

# %%
cf1 is cf2 #is the same object
# Out:
# False

# %%
cf1 is not cf2 #is not the same object
# Out:
# True

# %% [markdown]
# Logical Operators

# %%
cf1 = 50
cf2 = 60

# %%
True and True
# Out:
# True

# %%
cf1 < 100 and cf2 == 60
# Out:
# True

# %%
True and False
# Out:
# False

# %%
cf1 < 100 and cf2 == 70
# Out:
# False

# %%
False and False
# Out:
# False

# %%
True or True
# Out:
# True

# %%
cf1 < 100 or cf2 == 60
# Out:
# True

# %%
True or False
# Out:
# True

# %%
cf1 < 100 or cf2 == 70
# Out:
# True

# %%
False or False
# Out:
# False

# %%
not False
# Out:
# True

# %%
not True
# Out:
# False

# %%
not cf1 < 100
# Out:
# False

# %%
not(cf1 < 100 and cf2 == 70)
# Out:
# True

# %% [markdown]
# Membership Operators

# %%
cf = [-200, 20, 50, 70, 100, 50]
cf
# Out:
# [-200, 20, 50, 70, 100, 50]

# %%
20 in cf
# Out:
# True

# %%
30 in cf
# Out:
# False

# %%
company_name = "Facebook"
company_name
# Out:
# 'Facebook'

# %%
"d" not in company_name
# Out:
# True

# %%
"F" not in company_name
# Out:
# False
